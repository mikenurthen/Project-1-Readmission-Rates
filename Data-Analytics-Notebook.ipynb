# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from pathlib import Path

# %%
# Load in average readmissions data and read
average_readmission_clean_csv = Path("Output/Average_Readmission_Clean.csv")
average_readmission_clean = pd.read_csv(average_readmission_clean_csv)
average_readmission_clean
# Out:
#        state                           Race  % Readmission
# 0    ALABAMA  American Indian/Alaska native      15.767442
# 1    ALABAMA         Asian/Pacific islander      15.480000
# 2    ALABAMA                          Black      15.403689
# 3    ALABAMA                       Hispanic      15.300654
# 4    ALABAMA                          Other      15.555556
# ..       ...                            ...            ...
# 303  WYOMING         Asian/Pacific islander      15.181818
# 304  WYOMING                          Black      15.000000
# 305  WYOMING                       Hispanic      14.988764
# 306  WYOMING                          Other      15.062500
# 307  WYOMING                          White      15.242424
#
# [308 rows x 3 columns]

# %%
# Convert to dataframe
average_readmission_clean_df = pd.DataFrame(average_readmission_clean)
# Find average readmission rate per state so we can find worst 4 states and best 4 states (% Readmission)
avg_readmissions_by_state = average_readmission_clean_df.groupby('state')['% Readmission'].mean()
avg_read_state_df = pd.DataFrame(avg_readmissions_by_state)
avg_read_state_df.head(10)
# Out:
#                       % Readmission
# state
# ALABAMA                   15.478021
# ALASKA                    14.172724
# ARIZONA                   15.015916
# ARKANSAS                  15.829309
# CALIFORNIA                15.387323
# COLORADO                  14.612978
# CONNECTICUT               16.042437
# DELAWARE                  15.629630
# DISTRICT OF COLUMBIA      16.743056
# FLORIDA                   16.302045

# %%
plt.figure(figsize=(12, 5))
plt.bar(avg_read_state_df.index, avg_read_state_df['% Readmission'], color='skyblue', width=0.6)
plt.xlabel('State')
plt.ylabel('% Readmission')
plt.title('All States by Average Readmission Percentage')
plt.xticks(rotation=90, ha='right')
plt.tight_layout()
plt.show()

# %%
# Get worst 4 states by % Readmission
worst_sorted_states = avg_readmissions_by_state.sort_values(ascending=False)
# Get the worst 4 states
worst_4_states = worst_sorted_states.head(4)
worst_4_states_df = pd.DataFrame(worst_4_states)
worst_4_states_df
# Out:
#                       % Readmission
# state
# DISTRICT OF COLUMBIA      16.743056
# MASSACHUSETTS             16.706773
# NEW JERSEY                16.568565
# NEW YORK                  16.498212

# %%
# Get best 4 states by % Readmission
best_sorted_states = avg_readmissions_by_state.sort_values(ascending=True)
# Get the best 4 states
best_4_states = best_sorted_states.head(4)
best_4_states_df = pd.DataFrame(best_4_states)
best_4_states_df
# Out:
#         % Readmission
# state
# IDAHO       14.127872
# HAWAII      14.171429
# ALASKA      14.172724
# UTAH        14.367306

# %%
plt.figure(figsize=(12, 6))

# Plot best 4 states data with green bars
plt.bar(best_4_states_df.index, best_4_states_df['% Readmission'], color='red', width=0.8, label='Best 4 States (% Readmission)')

# Plot worst 4 states with blue bars
plt.bar(worst_4_states_df.index, worst_4_states_df['% Readmission'], color='skyblue', width=0.8, label='Worst 4 States (% Readmission)')

# Adding labels and title
plt.xlabel('State')
plt.ylabel('% Readmission')
plt.title('Readmission Percentage by State (Best 4 vs Worst 4)')
plt.xticks(rotation=45, ha='right')
plt.legend()  # Show legend with labels for each set of bars
plt.tight_layout()
plt.show()

# %%
best_4_states = ['IDAHO', 'HAWAII', 'ALASKA', 'UTAH']

filtered_df1 = average_readmission_clean_df[average_readmission_clean_df['state'].str.upper().isin(best_4_states)]
filtered_df1
# Out:
#       state                           Race  % Readmission
# 6    ALASKA  American Indian/Alaska native      15.000000
# 7    ALASKA         Asian/Pacific islander      14.173913
# 8    ALASKA                          Black      14.000000
# 9    ALASKA                       Hispanic      13.925926
# 10   ALASKA                          Other      13.333333
# 11   ALASKA                          White      14.603175
# 66   HAWAII  American Indian/Alaska native      13.600000
# 67   HAWAII         Asian/Pacific islander      14.277778
# 68   HAWAII                          Black      14.095238
# 69   HAWAII                       Hispanic      14.333333
# 70   HAWAII                          Other      14.361111
# 71   HAWAII                          White      14.361111
# 72    IDAHO  American Indian/Alaska native      14.250000
# 73    IDAHO         Asian/Pacific islander      13.833333
# 74    IDAHO                          Black      13.615385
# 75    IDAHO                       Hispanic      14.357143
# 76    IDAHO                          Other      13.731707
# 77    IDAHO                          White      14.979661
# 267    UTAH  American Indian/Alaska native      14.491525
# 268    UTAH         Asian/Pacific islander      14.022222
# 269    UTAH                          Black      14.116279
# 270    UTAH                       Hispanic      14.597701
# 271    UTAH                          Other      14.050000
# 272    UTAH                          White      14.926108

# %%
# Reset the index for filtered_df1
filtered_df1 = filtered_df1.groupby(['state', 'Race']).mean().reset_index()
filtered_df1
# Out:
#      state                           Race  % Readmission
# 0   ALASKA  American Indian/Alaska native      15.000000
# 1   ALASKA         Asian/Pacific islander      14.173913
# 2   ALASKA                          Black      14.000000
# 3   ALASKA                       Hispanic      13.925926
# 4   ALASKA                          Other      13.333333
# 5   ALASKA                          White      14.603175
# 6   HAWAII  American Indian/Alaska native      13.600000
# 7   HAWAII         Asian/Pacific islander      14.277778
# 8   HAWAII                          Black      14.095238
# 9   HAWAII                       Hispanic      14.333333
# 10  HAWAII                          Other      14.361111
# 11  HAWAII                          White      14.361111
# 12   IDAHO  American Indian/Alaska native      14.250000
# 13   IDAHO         Asian/Pacific islander      13.833333
# 14   IDAHO                          Black      13.615385
# 15   IDAHO                       Hispanic      14.357143
# 16   IDAHO                          Other      13.731707
# 17   IDAHO                          White      14.979661
# 18    UTAH  American Indian/Alaska native      14.491525
# 19    UTAH         Asian/Pacific islander      14.022222
# 20    UTAH                          Black      14.116279
# 21    UTAH                       Hispanic      14.597701
# 22    UTAH                          Other      14.050000
# 23    UTAH                          White      14.926108

# %%
states = filtered_df1['state'].unique()
races = filtered_df1['Race'].unique()

# Create bar chart
plt.figure(figsize=(12, 8))
bar_width = 0.1
index = range(len(states))
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b']

# Plot each race for each state
for i, race in enumerate(races):
    race_data = filtered_df1[filtered_df1['Race'] == race]
    plt.bar([p + i * bar_width for p in index], race_data['% Readmission'], bar_width, label=race, color=colors[i])
    # Add labels on top each bar
    for j, percentage in enumerate(race_data['% Readmission']):
        plt.text(index[j] + i * bar_width, percentage + 0.2, f'{percentage:.2f}%', ha='center', va='bottom', rotation=90)

plt.xlabel('States')
plt.ylabel('% Readmission')
plt.title('Readmission Percentage by Race (Best 4 States)')
plt.xticks([p + bar_width * len(states) / 2 for p in index], states)
plt.legend(loc='lower right')
plt.xticks(rotation=45)
plt.ylim(0, 17.5)
plt.tight_layout()
plt.show()

# %%
worst_4_states = ['DISTRICT OF COLUMBIA', 'MASSACHUSETTS', 'NEW JERSEY', 'NEW YORK']

filtered_df2 = average_readmission_clean_df[average_readmission_clean_df['state'].str.upper().isin(worst_4_states)]
filtered_df2
# Out:
#                     state                           Race  % Readmission
# 48   DISTRICT OF COLUMBIA  American Indian/Alaska native      17.125000
# 49   DISTRICT OF COLUMBIA         Asian/Pacific islander      16.777778
# 50   DISTRICT OF COLUMBIA                          Black      16.777778
# 51   DISTRICT OF COLUMBIA                       Hispanic      16.777778
# 52   DISTRICT OF COLUMBIA                          Other      16.555556
# 53   DISTRICT OF COLUMBIA                          White      16.444444
# 126         MASSACHUSETTS  American Indian/Alaska native      16.860000
# 127         MASSACHUSETTS         Asian/Pacific islander      16.765306
# 128         MASSACHUSETTS                          Black      16.628319
# 129         MASSACHUSETTS                       Hispanic      16.697248
# 130         MASSACHUSETTS                          Other      16.765957
# 131         MASSACHUSETTS                          White      16.523810
# 180            NEW JERSEY  American Indian/Alaska native      16.740741
# 181            NEW JERSEY         Asian/Pacific islander      16.568306
# 182            NEW JERSEY                          Black      16.606383
# 183            NEW JERSEY                       Hispanic      16.558511
# 184            NEW JERSEY                          Other      16.480000
# 185            NEW JERSEY                          White      16.457447
# 192              NEW YORK  American Indian/Alaska native      16.682119
# 193              NEW YORK         Asian/Pacific islander      16.591489
# 194              NEW YORK                          Black      16.497268
# 195              NEW YORK                       Hispanic      16.470588
# 196              NEW YORK                          Other      16.533808
# 197              NEW YORK                          White      16.214000

# %%
# Reset the index for filtered_df2
filtered_df2 = filtered_df2.groupby(['state', 'Race']).mean().reset_index()
filtered_df2
# Out:
#                    state                           Race  % Readmission
# 0   DISTRICT OF COLUMBIA  American Indian/Alaska native      17.125000
# 1   DISTRICT OF COLUMBIA         Asian/Pacific islander      16.777778
# 2   DISTRICT OF COLUMBIA                          Black      16.777778
# 3   DISTRICT OF COLUMBIA                       Hispanic      16.777778
# 4   DISTRICT OF COLUMBIA                          Other      16.555556
# 5   DISTRICT OF COLUMBIA                          White      16.444444
# 6          MASSACHUSETTS  American Indian/Alaska native      16.860000
# 7          MASSACHUSETTS         Asian/Pacific islander      16.765306
# 8          MASSACHUSETTS                          Black      16.628319
# 9          MASSACHUSETTS                       Hispanic      16.697248
# 10         MASSACHUSETTS                          Other      16.765957
# 11         MASSACHUSETTS                          White      16.523810
# 12            NEW JERSEY  American Indian/Alaska native      16.740741
# 13            NEW JERSEY         Asian/Pacific islander      16.568306
# 14            NEW JERSEY                          Black      16.606383
# 15            NEW JERSEY                       Hispanic      16.558511
# 16            NEW JERSEY                          Other      16.480000
# 17            NEW JERSEY                          White      16.457447
# 18              NEW YORK  American Indian/Alaska native      16.682119
# 19              NEW YORK         Asian/Pacific islander      16.591489
# 20              NEW YORK                          Black      16.497268
# 21              NEW YORK                       Hispanic      16.470588
# 22              NEW YORK                          Other      16.533808
# 23              NEW YORK                          White      16.214000

# %%
states = filtered_df2['state'].unique()
races = filtered_df2['Race'].unique()

# Create bar chart
plt.figure(figsize=(12, 8))
bar_width = 0.1
index = range(len(states))
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b']

# Plot each race for each state
for i, race in enumerate(races):
    race_data = filtered_df2[filtered_df2['Race'] == race]
    plt.bar([p + i * bar_width for p in index], race_data['% Readmission'], bar_width, label=race, color=colors[i])
    # Add labels on top each bar
    for j, percentage in enumerate(race_data['% Readmission']):
        plt.text(index[j] + i * bar_width, percentage + 0.2, f'{percentage:.2f}%', ha='center', va='bottom', rotation=90)

plt.xlabel('States')
plt.ylabel('% Readmission')
plt.title('Readmission Percentage by Race (Worst 4 States)')
plt.xticks([p + bar_width * len(states) / 2 for p in index], states)
plt.legend(loc='lower right')
plt.xticks(rotation=45)
plt.ylim(0, 21)
plt.tight_layout()
plt.show()

# %%
# Create stacked bar chart for best 4 states

states = filtered_df1['state'].unique()
races = filtered_df1['Race'].unique()

plt.figure(figsize=(12, 8))

bar_width = 0.5
index = range(len(states))
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b']
bottom = [0] * len(states)

# Plot each race for each state
for i, race in enumerate(races):
    race_data = filtered_df1[filtered_df1['Race'] == race]
    race_percentages = race_data['% Readmission']
    plt.bar(index, race_percentages, bar_width, label=race, color=colors[i], bottom=bottom)
    # Add labels within bars
    for j, percentage in enumerate(race_percentages):
        plt.text(index[j], bottom[j] + percentage / 2, f'{percentage:.2f}%', ha='center', va='center', color='white')
    bottom = [bottom[j] + percentage for j, percentage in enumerate(race_percentages)]

plt.xlabel('States')
plt.ylabel('% Readmission')
plt.title('Readmission Percentages by Race (Best 4 States)')
plt.xticks(index, states)
plt.legend(loc='best')
plt.xticks(rotation=45)
plt.ylim(0, 132) 
plt.tight_layout()
plt.show()

# %%
# Create stacked bar chart for worst 4 states

states = filtered_df2['state'].unique()
races = filtered_df2['Race'].unique()

plt.figure(figsize=(12, 8))

bar_width = 0.5
index = range(len(states))
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b']
bottom = [0] * len(states)

# Plot each race for each state
for i, race in enumerate(races):
    race_data = filtered_df2[filtered_df2['Race'] == race]
    race_percentages = race_data['% Readmission']
    plt.bar(index, race_percentages, bar_width, label=race, color=colors[i], bottom=bottom)
    # Add labels within bars
    for j, percentage in enumerate(race_percentages):
        plt.text(index[j], bottom[j] + percentage / 2, f'{percentage:.2f}%', ha='center', va='center', color='white')
    bottom = [bottom[j] + percentage for j, percentage in enumerate(race_percentages)]

plt.xlabel('States')
plt.ylabel('% Readmission')
plt.title('Readmission Percentages by Race (Worst 4 States)')
plt.xticks(index, states)
plt.legend(loc='best')
plt.xticks(rotation=45)
plt.ylim(0, 130) 
plt.tight_layout()
plt.show()

# %%
# Load in census data and read
state_census_clean_csv = Path("Output/Selected_States.csv")
state_census_clean = pd.read_csv(state_census_clean_csv)
# state_census_clean

# %%
# Choose specific states to plot
states_to_plot = ["Alaska", "Hawaii", "Idaho", "Utah"]

# Filter data for the chosen states
state_data = state_census_clean[state_census_clean['State'].isin(states_to_plot)]

# Get unique income brackets
income_brackets = state_census_clean.columns[3:]

# Create a dictionary to store data for each state
state_data_dict = {}
for state in states_to_plot:
    state_data_dict[state] = state_data[state_data['State'] == state].set_index('Race')[income_brackets].T.to_dict()

# Plot multi-bar graphs for each state
num_states = len(states_to_plot)
num_rows = 2
num_cols = (num_states + 1) // num_rows

fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 8))

for i, state in enumerate(states_to_plot):
    ax = axes[i // num_cols, i % num_cols]
    races = list(state_data_dict[state].keys())
    num_races = len(races)
    bar_width = 0.2
    index = np.arange(len(income_brackets))
    
    for j, race in enumerate(races):
        bar_positions = index + j * bar_width - (bar_width * (num_races - 1) / 2)
        race_data = list(state_data_dict[state][race].values())
        ax.bar(bar_positions, race_data, bar_width, label=race)
    
    ax.set_title(state)
    ax.set_xlabel("Income Bracket")
    ax.set_ylabel("Total Households")
    ax.set_xticks(index)
    ax.set_xticklabels(income_brackets, rotation=45)
    ax.legend()

# Adjust layout
plt.tight_layout()
plt.show()

# %%
# Choose specific states to plot
states_to_plot = ["Alaska", "Hawaii", "Idaho", "Utah"]

# Filter data for the chosen states
state_data = state_census_clean[state_census_clean['State'].isin(states_to_plot)]

# Group data by state and race
top_readmission_data = state_data.groupby(['State', 'Race'])

# Get unique income brackets
income_brackets = state_census_clean.columns[3:]

# Plot bar charts for the chosen states
num_states = len(states_to_plot)
num_rows = 2
num_cols = (num_states + 1) // num_rows

fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 8))

for (state, race), top_readmission_df in top_readmission_data:
    index = states_to_plot.index(state)
    ax = axes[index // num_cols, index % num_cols]
    
    # Calculate total households for each income bracket
    total_households = top_readmission_df[income_brackets].sum()
    
    # Plot bar chart
    ax.bar(income_brackets, total_households, label=race)
    ax.set_title(f"{state}")
    ax.set_xlabel("Income Bracket")
    ax.set_ylabel("Total Households")
    ax.tick_params(axis='x', rotation=45)
    ax.legend()

# Adjust layout
plt.tight_layout()
plt.show()

# %%
# Choose specific states to plot
states_to_plot = ["District of Columbia", "Massachusetts", "New Jersey", "New York"]

# Filter data for the chosen states
state_data = state_census_clean[state_census_clean['State'].isin(states_to_plot)]

# Get unique income brackets
income_brackets = state_census_clean.columns[3:]

# Create a dictionary to store data for each state
state_data_dict = {}
for state in states_to_plot:
    state_data_dict[state] = state_data[state_data['State'] == state].set_index('Race')[income_brackets].T.to_dict()

# Plot multi-bar graphs for each state
num_states = len(states_to_plot)
num_rows = 2
num_cols = (num_states + 1) // num_rows

fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 8))

for i, state in enumerate(states_to_plot):
    ax = axes[i // num_cols, i % num_cols]
    races = list(state_data_dict[state].keys())
    num_races = len(races)
    bar_width = 0.2
    index = np.arange(len(income_brackets))
    
    for j, race in enumerate(races):
        bar_positions = index + j * bar_width - (bar_width * (num_races - 1) / 2)
        race_data = list(state_data_dict[state][race].values())
        ax.bar(bar_positions, race_data, bar_width, label=race)
    
    ax.set_title(state)
    ax.set_xlabel("Income Bracket")
    ax.set_ylabel("Total Households")
    ax.set_xticks(index)
    ax.set_xticklabels(income_brackets, rotation=45)
    ax.legend()

# Adjust layout
plt.tight_layout()
plt.show()

# %%
# Choose specific states to plot
states_to_plot = ["District of Columbia", "Massachusetts", "New Jersey", "New York"]

# Filter data for the chosen states
state_data = state_census_clean[state_census_clean['State'].isin(states_to_plot)]

# Group data by state and race
top_readmission_data = state_data.groupby(['State', 'Race'])

# Get unique income brackets
income_brackets = state_census_clean.columns[3:]

# Plot bar charts for the chosen states
num_states = len(states_to_plot)
num_rows = 2
num_cols = (num_states + 1) // num_rows

fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 8))

for (state, race), top_readmission_df in top_readmission_data:
    index = states_to_plot.index(state)
    ax = axes[index // num_cols, index % num_cols]
    
    # Calculate total households for each income bracket
    total_households = top_readmission_df[income_brackets].sum()
    
    # Plot bar chart
    ax.bar(income_brackets, total_households, label=race)
    ax.set_title(f"{state}")
    ax.set_xlabel("Income Bracket")
    ax.set_ylabel("Total Households")
    ax.tick_params(axis='x', rotation=45)
    ax.legend()

# Adjust layout
plt.tight_layout()
plt.show()

# %%
state_data.describe()
# Out:
#        Total Household           <10k     10k to 15k     15k to 25k  \
# count     2.700000e+01      27.000000      27.000000      27.000000
# mean      5.687361e+05   32817.962963   24562.000000   40968.259259
# std       1.071457e+06   51284.615033   40062.048488   72315.346822
# min       8.170000e+02      60.000000      17.000000      20.000000
# 25%       1.151300e+04    1034.000000     492.500000     700.000000
# 50%       1.625720e+05   11798.000000    8850.000000    9457.000000
# 75%       5.472665e+05   36114.000000   28225.000000   44405.000000
# max       4.977721e+06  224410.000000  179107.000000  336747.000000
#
#           25k to 35k     35k to 50k     50k to 75k    75k to 100k  \
# count      27.000000      27.000000      27.000000      27.000000
# mean    39470.222222   53992.148148   82515.222222   67141.703704
# std     70528.326796   97821.345389  154434.632299  129126.260719
# min        43.000000      56.000000      52.000000      25.000000
# 25%       721.500000    1015.000000    1699.000000    1201.500000
# 50%      9707.000000   13561.000000   20097.000000   16835.000000
# 75%     45117.000000   58722.500000   82282.500000   61191.000000
# max    333261.000000  459621.000000  727979.000000  601749.000000
#
#         100k to 150k   150k to 200k          200k+
# count      27.000000      27.000000      27.000000
# mean    94730.148148   54098.333333   78440.148148
# std    191033.055568  110491.963104  168368.622706
# min        47.000000      15.000000      59.000000
# 25%      1996.000000    1097.000000    1232.000000
# 50%     26509.000000   12704.000000   11687.000000
# 75%     76459.000000   43882.000000   59027.500000
# max    877368.000000  491711.000000  745768.000000
